# %% [markdown]
# # MCPify your AWS Lambda with Gateway OAuth Inbound
# ## Transform AWS Lambda functions into secure MCP tools with Bedrock AgentCore Gateway
#
# ## Overview
# Bedrock AgentCore Gateway provides customers a way to turn their existing AWS Lambda functions into fully-managed MCP servers without needing to manage infra or hosting. Gateway will provide a uniform Model Context Protocol (MCP) interface across all these tools. Gateway employs a dual authentication model to ensure secure access control for both incoming requests and outbound connections to target resources. The framework consists of two key components: Inbound Auth, which validates and authorizes users attempting to access gateway targets, and Outbound Auth, which enables the gateway to securely connect to backend resources on behalf of authenticated users. Gateways uses IAM role to authorize the calls to AWS Lambda functions for outbound authorization.
#
# In this example, we will demonstrate OAuth for inbound authorization and IAM roles for outbound authorization.
#
# ![How does it work](images/lambda-iam-gateway.png)
#
# ### Tutorial Details
#
#
# | Information          | Details                                                   |
# |:---------------------|:----------------------------------------------------------|
# | Tutorial type        | Interactive                                               |
# | AgentCore components | AgentCore Gateway, AgentCore Identity                     |
# | Agentic Framework    | Strands Agents                                            |
# | Gateway Target type  | AWS Lambda                                                |
# | Inbound Auth IdP     | Amazon Cognito                                            |
# | Outbound Auth        | AWS IAM                                                   |
# | LLM model            | Anthropic Claude Haiku 4.5, Amazon Nova Pro              |
# | Tutorial components  | Creating AgentCore Gateway and Invoking AgentCore Gateway |
# | Tutorial vertical    | Cross-vertical                                            |
# | Example complexity   | Easy                                                      |
# | SDK used             | boto3                                                     |
#
# In the first part of the tutorial we will create some AmazonCore Gateway targets
#
# ### Tutorial Architecture
# In this tutorial we will transform operations defined in AWS lambda function into MCP tools and host it in Bedrock AgentCore Gateway.
# For demonstration purposes, we will use a Strands Agent using Amazon Bedrock models
# In our example we will use a very simple agent with two tools: get_order and update_order.

# %% [markdown]
# ## Prerequisites
#
# To execute this tutorial you will need:
# * Jupyter notebook (Python kernel)
# * uv
# * AWS credentials
# * Amazon Cognito

# %% [markdown]
# ## Configuring Authentication for Incoming AgentCore Gateway Requests
# AgentCore Gateway provides secure connections via inbound and outbound authentication. For the inbound authentication, the AgentCore Gateway analyzes the OAuth token passed during invocation to decide allow or deny the access to a tool in the gateway. If a tool needs access to external resources, the AgentCore Gateway can use outbound authentication via API Key, IAM or OAuth Token to allow or deny the access to the external resource.
#
#
#
# During the inbound authorization flow, an agent or the MCP client calls an MCP tool in the AgentCore Gateway adding an OAuth access token (generated from the user’s IdP). AgentCore Gateway then validates the OAuth access token and performs inbound authorization.
#
# If the tool running in AgentCore Gateway needs to access external resources, OAuth will retrieve credentials of downstream resources using the resource credential provider for the Gateway target. AgentCore Gateway pass the authorization credentials to the caller to get access to the downstream API.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents==1.19.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from -r requirements.txt (line 3)) (1.19.0)
# Requirement already satisfied: strands-agents-tools==0.2.17 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from -r requirements.txt (line 6)) (0.2.17)
# Requirement already satisfied: bedrock-agentcore==1.1.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from -r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: boto3>=1.42.7 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from -r requirements.txt (line 12)) (1.42.8)
# Requirement already satisfied: requests>=2.31.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from -r requirements.txt (line 15)) (2.32.5)
# Requirement already satisfied: mcp>=1.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from -r requirements.txt (line 18)) (1.23.1)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (1.42.8)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (0.17.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (1.39.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (0.60b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (1.39.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents==1.19.0->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (2.10.1)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.27.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (9.1.2)
# Requirement already satisfied: tzdata in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: pre-commit>=4.2.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (4.5.0)
# Requirement already satisfied: starlette>=0.46.2 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (0.50.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: uvicorn>=0.34.2 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (0.38.0)
# Requirement already satisfied: websockets>=12.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (15.0.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from boto3>=1.42.7->-r requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from boto3>=1.42.7->-r requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from requests>=2.31.0->-r requirements.txt (line 15)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from requests>=2.31.0->-r requirements.txt (line 15)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from requests>=2.31.0->-r requirements.txt (line 15)) (2025.11.12)
# Requirement already satisfied: anyio>=4.5 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (2.12.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (3.0.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from mcp>=1.0.0->-r requirements.txt (line 18)) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.22.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from botocore<2.0.0,>=1.29.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (4.14.3)
# Requirement already satisfied: six<2,>=1.15 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (2.8)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents==1.19.0->-r requirements.txt (line 3)) (0.60b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents==1.19.0->-r requirements.txt (line 3)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from opentelemetry-instrumentation==0.60b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents==1.19.0->-r requirements.txt (line 3)) (0.60b0)
# Requirement already satisfied: packaging>=18.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from opentelemetry-instrumentation==0.60b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents==1.19.0->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: wcwidth in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (0.2.14)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents==1.19.0->-r requirements.txt (line 3)) (2.41.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (3.39.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from httpx>=0.27.1->mcp>=1.0.0->-r requirements.txt (line 18)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.0.0->-r requirements.txt (line 18)) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools==0.2.17->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (20.35.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pydantic-settings>=2.5.2->mcp>=1.0.0->-r requirements.txt (line 18)) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.0.0->-r requirements.txt (line 18)) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.0.0->-r requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.0.0->-r requirements.txt (line 18)) (2.23)
# Requirement already satisfied: click>=7.0 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from uvicorn>=0.34.2->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (8.3.1)
# Requirement already satisfied: colorama in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from click>=7.0->uvicorn>=0.34.2->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\r.laface\desktop\codice\aws-agentcore\.venv\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->bedrock-agentcore==1.1.1->-r requirements.txt (line 9)) (4.5.0)

# %%
# Set AWS credentials if not using Amazon SageMaker notebook
import os
# os.environ['AWS_ACCESS_KEY_ID'] = '' # Set the access key
# os.environ['AWS_SECRET_ACCESS_KEY'] = '' # Set the secret key
os.environ['AWS_DEFAULT_REGION'] = os.environ.get('AWS_REGION', 'us-east-1') # set the AWS region

# %%
import os
import sys

# Get the directory of the current script
if '__file__' in globals():
    current_dir = os.path.dirname(os.path.abspath(__file__))
else:
    current_dir = os.getcwd()  # Fallback if __file__ is not defined (e.g., Jupyter)

# Navigate to the directory containing utils.py (one level up)
utils_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add to sys.path
sys.path.insert(0, utils_dir)

# Now you can import utils
import utils

# %%
# #### Create a sample AWS Lambda function that you want to convert into MCP tools
# lambda_resp = utils.create_gateway_lambda("lambda_function_code.zip")

# if lambda_resp is not None:
#     if lambda_resp['exit_code'] == 0:
#         print("Lambda function created with ARN: ", lambda_resp['lambda_function_arn'])
#     else:
#         print("Lambda function creation failed with message: ", lambda_resp['lambda_function_arn'])

# %%
# #### Create an IAM role for the Gateway to assume
# import utils
# agentcore_gateway_iam_role = utils.create_agentcore_gateway_role("sample-lambdagateway")
# print("Agentcore gateway role ARN: ", agentcore_gateway_iam_role['Role']['Arn'])

# %% [markdown]
# # Create Amazon Cognito Pool for Inbound authorization to Gateway

# %%
# # Creating Cognito User Pool 
# import os
# import boto3
# import requests
# import time
# from botocore.exceptions import ClientError

# REGION = os.environ['AWS_DEFAULT_REGION']
# USER_POOL_NAME = "sample-agentcore-gateway-pool"
# RESOURCE_SERVER_ID = "sample-agentcore-gateway-id"
# RESOURCE_SERVER_NAME = "sample-agentcore-gateway-name"
# CLIENT_NAME = "sample-agentcore-gateway-client"
# SCOPES = [
#     {"ScopeName": "gateway:read", "ScopeDescription": "Read access"},
#     {"ScopeName": "gateway:write", "ScopeDescription": "Write access"}
# ]
# scopeString = f"{RESOURCE_SERVER_ID}/gateway:read {RESOURCE_SERVER_ID}/gateway:write"

# cognito = boto3.client("cognito-idp", region_name=REGION)

# print("Creating or retrieving Cognito resources...")
# user_pool_id = utils.get_or_create_user_pool(cognito, USER_POOL_NAME)
# print(f"User Pool ID: {user_pool_id}")

# utils.get_or_create_resource_server(cognito, user_pool_id, RESOURCE_SERVER_ID, RESOURCE_SERVER_NAME, SCOPES)
# print("Resource server ensured.")

# client_id, client_secret  = utils.get_or_create_m2m_client(cognito, user_pool_id, CLIENT_NAME, RESOURCE_SERVER_ID)
# print(f"Client ID: {client_id}")

# # Get discovery URL  
# cognito_discovery_url = f'https://cognito-idp.{REGION}.amazonaws.com/{user_pool_id}/.well-known/openid-configuration'
# print(cognito_discovery_url)

# %% [markdown]
# # Create the Gateway with Amazon Cognito Authorizer for inbound authorization

# %%
# # CreateGateway with Cognito authorizer without CMK. Use the Cognito user pool created in the previous step
# gateway_client = boto3.client('bedrock-agentcore-control', region_name = os.environ['AWS_DEFAULT_REGION'])
# auth_config = {
#     "customJWTAuthorizer": { 
#         "allowedClients": [client_id],  # Client MUST match with the ClientId configured in Cognito. Example: 7rfbikfsm51j2fpaggacgng84g
#         "discoveryUrl": cognito_discovery_url
#     }
# }
# create_response = gateway_client.create_gateway(name='TestGWforLambda',
#     roleArn = agentcore_gateway_iam_role['Role']['Arn'], # The IAM Role must have permissions to create/list/get/delete Gateway 
#     protocolType='MCP',
#     authorizerType='CUSTOM_JWT',
#     authorizerConfiguration=auth_config, 
#     description='AgentCore Gateway with AWS Lambda target type'
# )
# print(create_response)
# # Retrieve the GatewayID used for GatewayTarget creation
# gatewayID = create_response["gatewayId"]
# gatewayURL = create_response["gatewayUrl"]
# print(gatewayID)

# %% [markdown]
# # Create an AWS Lambda target and transform into MCP tools

# %%
#with existing lambda

import boto3

gateway_client = boto3.client('bedrock-agentcore-control', region_name = os.environ['AWS_DEFAULT_REGION'])
lambda_arn="arn:aws:lambda:us-east-1:879338784410:function:PersonalAssistant-TaskPost"
gatewayID="arn:aws:bedrock-agentcore:us-east-1:879338784410:gateway/taskapigateway-vveeifneus"

# %%
# # Schema configurato per Lambda POST di task management
# lambda_target_config = {
#     "mcp": {
#         "lambda": {
#             "lambdaArn": lambda_arn,
#             "toolSchema": {
#                 "inlinePayload": [
#                     {
#                         "name": "save-task",
#                         "description": "Crea o aggiorna un task nel sistema di gestione task. Usa questo tool per salvare nuovi task o modificare task esistenti con titolo, descrizione, scadenza e priorità.",
#                         "inputSchema": {
#                             "type": "object",
#                             "description": "Parametri per creare o aggiornare un task",
#                             "properties": {
#                                 "title": {
#                                     "type": "string",
#                                     "description": "Titolo del task (obbligatorio)"
#                                 },
#                                 "description": {
#                                     "type": "string",
#                                     "description": "Descrizione dettagliata del task"
#                                 },
#                                 "dueDate": {
#                                     "type": "string",
#                                     "description": "Data di scadenza del task in formato ISO 8601 (es: 2025-12-13T18:00:00Z)"
#                                 },
#                                 "priority": {
#                                     "type": "string",
#                                     "description": "Priorità del task. Valori consentiti: 'low' (bassa), 'medium' (media), 'high' (alta)"
#                                 },
#                                 "status": {
#                                     "type": "string",
#                                     "description": "Stato del task. Valori consentiti: 'pending' (da fare), 'in_progress' (in corso), 'completed' (completato)"
#                                 },
#                                 "taskId": {
#                                     "type": "string",
#                                     "description": "ID del task (solo per aggiornamenti, lasciare vuoto per nuovi task)"
#                                 }
#                             },
#                             "required": ["title"]
#                         }
#                     }
#                 ]
#             }
#         }
#     }
# }

# credential_config = [ 
#     {
#         "credentialProviderType": "GATEWAY_IAM_ROLE"
#     }
# ]

# targetname = 'save-task'

# response = gateway_client.create_gateway_target(
#     gatewayIdentifier=gatewayID,
#     name=targetname,
#     description='Lambda Target per aggiunta task - POST',
#     targetConfiguration=lambda_target_config,
#     credentialProviderConfigurations=credential_config
# )
# print(f"Gateway target creato: {response}")
# Out:
# ---------------------------------------------------------------------------
# AccessDeniedException                     Traceback (most recent call last)
# Cell In[25], line 57
#      49 credential_config = [
#      50     {
#      51         "credentialProviderType": "GATEWAY_IAM_ROLE"
#      52     }
#      53 ]
#      55 targetname = 'save-task'
# ---> 57 response = gateway_client.create_gateway_target(
#      58     gatewayIdentifier=gatewayID,
#      59     name=targetname,
#      60     description='Lambda Target per aggiunta task - POST',
#      61     targetConfiguration=lambda_target_config,
#      62     credentialProviderConfigurations=credential_config
#      63 )
#      64 print(f"Gateway target creato: {response}")
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# AccessDeniedException: An error occurred (AccessDeniedException) when calling the CreateGatewayTarget operation: User: arn:aws:iam::879338784410:user/rosario.laface is not authorized to perform: bedrock-agentcore:CreateGatewayTarget

# %% [markdown]
# # Calling Bedrock AgentCore Gateway from a Strands Agent
#
# The Strands agent seamlessly integrates with AWS tools through the Bedrock AgentCore Gateway, which implements the Model Context Protocol (MCP) specification. This integration enables secure, standardized communication between AI agents and AWS services.
#
# At its core, the Bedrock AgentCore Gateway serves as a protocol-compliant Gateway that exposes fundamental MCP APIs: ListTools and InvokeTools. These APIs allow any MCP-compliant client or SDK to discover and interact with available tools in a secure, standardized way. When the Strands agent needs to access AWS services, it communicates with the Gateway using these MCP-standardized endpoints.
#
# The Gateway's implementation adheres strictly to the (MCP Authorization specification)[https://modelcontextprotocol.org/specification/draft/basic/authorization], ensuring robust security and access control. This means that every tool invocation by the Strands agent goes through authorization step, maintaining security while enabling powerful functionality.
#
# For example, when the Strands agent needs to access MCP tools, it first calls ListTools to discover available tools, then uses InvokeTools to execute specific actions. The Gateway handles all the necessary security validations, protocol translations, and service interactions, making the entire process seamless and secure.
#
# This architectural approach means that any client or SDK that implements the MCP specification can interact with AWS services through the Gateway, making it a versatile and future-proof solution for AI agent integrations.
#
# ![Strands agent calling Gateway](images/strands-lambda-gateway.png)

# %% [markdown]
# # Request the access token from Amazon Cognito for inbound authorization

# %%
# import time
# time.sleep(10)

# %%
user_pool_id="us-east-1_F8frcQSD7"
client_id="40ipvfb7kr5hnjqm06555e5hlp"
client_secret  = "6rtmm58udin800qd6eiufv8top19q615m57etqha4fn9opmbi3f"
scopeString="TaskAPIGateway/invoke"
gatewayURL="https://taskapigateway-vveeifneus.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp"
REGION = 'us-east-1'

# %%
import requests
import base64

# IMPORTANTE: Usa il dominio Cognito corretto (NON derivato dal pool ID)
cognito_domain = "agentcore-85bb2461"  # Questo è il dominio configurato in Cognito
token_url = f"https://{cognito_domain}.auth.{REGION}.amazoncognito.com/oauth2/token"

# Request token usando client credentials flow
headers = {
    'Content-Type': 'application/x-www-form-urlencoded'
}

data = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
    'scope': scopeString
}

response = requests.post(token_url, headers=headers, data=data)
response.raise_for_status()  # Solleva eccezione se fallisce
token_response = response.json()
token = token_response.get('access_token')

print(f"Access token: {token[:50]}...")
# Out:
# Access token: eyJraWQiOiJFNjBIK24zSUdxWllBMnZKNDJtNkZNMHlYY2tGcm...

# %%
print("Requesting the access token from Amazon Cognito authorizer...")
# token_response = utils.get_token(user_pool_id, client_id, client_secret,scopeString,REGION)
# print(token_response)
# token = token_response["access_token"]
print("Token response:", token)
# Out:
# Requesting the access token from Amazon Cognito authorizer...
# Token response: eyJraWQiOiJFNjBIK24zSUdxWllBMnZKNDJtNkZNMHlYY2tGcmFRekNFbzZ2UTVxVVpnPSIsImFsZyI6IlJTMjU2In0.....gUVbHNXf4LkNmvxfPVsg8tGtDusKATk0tqLw-hH_g4gg8mbRrStK7U8BScAL-irM7Ra-LIWdwrDv6Jg_N6GO1dnFVPOG9PGGxcFdSIK04Z-ipLG8Q59LC_QBzUVb-N6df9-89UL0nBJaRn0OZbQ_ThQvL70q-JFkskK2c65L7Uj_s5RS7BqzseAgoah95UZ-D0l8D0LJ6YdZNmPBBMrCTnsxBIucHeh3T1uT6-M9DVynWbKyiJy0EoBQHA_KN-vHtbZjqVjgmqu3atK10MsNoWn1YIBLfBGfKP51gnPskTEIET6EmuPbmAQ_7oKU50-Ge2A4slNOJYSbC5DqeNVSVw

# %% [markdown]
# # Strands agent calling MCP tools of AWS Lambda using Bedrock AgentCore Gateway

# %%
from strands.models import BedrockModel
from mcp.client.streamable_http import streamablehttp_client 
from strands.tools.mcp.mcp_client import MCPClient
from strands import Agent

def create_streamable_http_transport():
    return streamablehttp_client(gatewayURL,headers={"Authorization": f"Bearer {token}"})

client = MCPClient(create_streamable_http_transport)

## The IAM credentials configured in ~/.aws/credentials should have access to Bedrock model
yourmodel = BedrockModel(
    model_id="us.amazon.nova-pro-v1:0",
    temperature=0.7,
)

# %%
from strands import Agent
import logging


# Configure the root strands logger. Change it to DEBUG if you are debugging the issue.
logging.getLogger("strands").setLevel(logging.INFO)

# Add a handler to see the logs
logging.basicConfig(
    format="%(levelname)s | %(name)s | %(message)s", 
    handlers=[logging.StreamHandler()]
)

with client:
    # Call the listTools 
    tools = client.list_tools_sync()
    # Create an Agent with the model and tools
    agent = Agent(model=yourmodel,tools=tools) ## you can replace with any model you like
    print(f"Tools loaded in the agent are {agent.tool_names}")
    # print(f"Tools configuration in the agent are {agent.tool_config}")
    # Invoke the agent with the sample prompt. This will only invoke  MCP listTools and retrieve the list of tools the LLM has access to. The below does not actually call any tool.
    agent("Hi , can you list all tools available to you")
    # Invoke the agent with sample prompt, invoke the tool and display the response
    agent("Aggiungi un task: 'Comprare il latte' con scadenza domani alle 18:00")
    # Call the MCP tool explicitly. The MCP Tool name and arguments must match with your AWS Lambda function or the OpenAPI/Smithy API
# Out:
# Tools loaded in the agent are ['x_amz_bedrock_agentcore_search', 'get-tasks___get-tasks', 'save-task___save-task']
# <thinking> The user has requested a list of all available tools. I should provide this information directly without needing to use any tools. </thinking>
#
# Here are the tools available to me:
#
# 1. **x_amz_bedrock_agentcore_search**
#    - Description: A special tool that returns a trimmed down list of tools given a context. Use this tool only when there are many tools available and you want to get a subset that matches the provided context.
#    - Parameters:
#      - `query` (required): Property query
#
# 2. **get-tasks___get-tasks**
#    - Description: Retrieve tasks from database
#    - Parameters:
#      - `due_date`: Property due_date
#      - `status`: Property status
#
# 3. **save-task___save-task**
#    - Description: Create or update a task in the task management system. Use `taskId` to update an existing task, otherwise create a new task.
#    - Parameters:
#      - `description`: Detailed description of the task
#      - `priority`: Priority of the task. Allowed values: low, medium, high
#      - `title` (required): Title of the task
#      - `taskId`: ID of the existing task to update. If omitted, a new task is created.
#      - `dueDate`: Due date of the task in ISO 8601 format (YYYY-MM-DD)
#      - `status`: Status of the task. Allowed values: pending, in_progress, completed<thinking> The user wants to add a task with the title "Comprare il latte" and a due date of tomorrow at 18:00. I need to use the `save-task___
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# Cell In[30], line 24
#      22 agent("Hi , can you list all tools available to you")
#      23 # Invoke the agent with sample prompt, invoke the tool and display the response
# ---> 24 agent("Aggiungi un task: 'Comprare il latte' con scadenza domani alle 18:00")
#      25 # Call the MCP tool explicitly. The MCP Tool name and arguments must match with your AWS Lambda function or the OpenAPI/Smithy API
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\agent\agent.py:349, in Agent.__call__(self, prompt, invocation_state, structured_output_model, **kwargs)
#     314 def __call__(
#     315     self,
#     316     prompt: AgentInput = None,
#    (...)    320     **kwargs: Any,
#     321 ) -> AgentResult:
#     322     """Process a natural language prompt through the agent's event loop.
#     323
#     324     This method implements the conversational interface with multiple input patterns:
#    (...)    347             - structured_output: Parsed structured output when structured_output_model was specified
#     348     """
# --> 349     return run_async(
#     350         lambda: self.invoke_async(
#     351             prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     352         )
#     353     )
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\_async.py:33, in run_async(async_func)
#      31 context = contextvars.copy_context()
#      32 future = executor.submit(context.run, execute)
# ---> 33 return future.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\_async.py:28, in run_async.<locals>.execute()
#      27 def execute() -> T:
# ---> 28     return asyncio.run(execute_async())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\asyncio\runners.py:195, in run(main, debug, loop_factory)
#     191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 195     return runner.run(main)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\asyncio\runners.py:118, in Runner.run(self, coro, context)
#     116 self._interrupt_count = 0
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#     120     if self._interrupt_count > 0:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:691, in BaseEventLoop.run_until_complete(self, future)
#     688 if not future.done():
#     689     raise RuntimeError('Event loop stopped before Future completed.')
# --> 691 return future.result()
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\_async.py:25, in run_async.<locals>.execute_async()
#      24 async def execute_async() -> T:
# ---> 25     return await async_func()
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\agent\agent.py:392, in Agent.invoke_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     363 """Process a natural language prompt through the agent's event loop.
#     364
#     365 This method implements the conversational interface with multiple input patterns:
#    (...)    387         - state: The final state of the event loop
#     388 """
#     389 events = self.stream_async(
#     390     prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     391 )
# --> 392 async for event in events:
#     393     _ = event
#     395 return cast(AgentResult, event["result"])
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\agent\agent.py:588, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     585 try:
#     586     events = self._run_loop(messages, merged_state, structured_output_model)
# --> 588     async for event in events:
#     589         event.prepare(invocation_state=merged_state)
#     591         if event.is_callback_event:
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\agent\agent.py:636, in Agent._run_loop(self, messages, invocation_state, structured_output_model)
#     634 # Execute the event loop cycle with retry logic for context limits
#     635 events = self._execute_event_loop_cycle(invocation_state, structured_output_context)
# --> 636 async for event in events:
#     637     # Signal from the model provider that the message sent by the user should be redacted,
#     638     # likely due to a guardrail.
#     639     if (
#     640         isinstance(event, ModelStreamChunkEvent)
#     641         and event.chunk
#     642         and event.chunk.get("redactContent")
#     643         and event.chunk["redactContent"].get("redactUserContentMessage")
#     644     ):
#     645         self.messages[-1]["content"] = self._redact_user_content(
#     646             self.messages[-1]["content"], str(event.chunk["redactContent"]["redactUserContentMessage"])
#     647         )
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\agent\agent.py:684, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context)
#     678 try:
#     679     events = event_loop_cycle(
#     680         agent=self,
#     681         invocation_state=invocation_state,
#     682         structured_output_context=structured_output_context,
#     683     )
# --> 684     async for event in events:
#     685         yield event
#     687 except ContextWindowOverflowException as e:
#     688     # Try reducing the context size and retrying
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\event_loop\event_loop.py:155, in event_loop_cycle(agent, invocation_state, structured_output_context)
#     151 else:
#     152     model_events = _handle_model_execution(
#     153         agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     154     )
# --> 155     async for model_event in model_events:
#     156         if not isinstance(model_event, ModelStopReason):
#     157             yield model_event
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\event_loop\event_loop.py:400, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     398                 yield EventLoopThrottleEvent(delay=current_delay)
#     399             else:
# --> 400                 raise e
#     402 try:
#     403     # Add message in trace and mark the end of the stream messages trace
#     404     stream_trace.add_message(message)
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\event_loop\event_loop.py:341, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     339     tool_specs = agent.tool_registry.get_all_tool_specs()
#     340 try:
# --> 341     async for event in stream_messages(
#     342         agent.model,
#     343         agent.system_prompt,
#     344         agent.messages,
#     345         tool_specs,
#     346         system_prompt_content=agent._system_prompt_content,
#     347         tool_choice=structured_output_context.tool_choice,
#     348     ):
#     349         yield event
#     351     stop_reason, message, usage, metrics = event["stop"]
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\event_loop\streaming.py:457, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice, system_prompt_content, **kwargs)
#     447 start_time = time.time()
#     449 chunks = model.stream(
#     450     messages,
#     451     tool_specs if tool_specs else None,
#    (...)    454     system_prompt_content=system_prompt_content,
#     455 )
# --> 457 async for event in process_stream(chunks, start_time):
#     458     yield event
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\event_loop\streaming.py:391, in process_stream(chunks, start_time)
#     388 usage: Usage = Usage(inputTokens=0, outputTokens=0, totalTokens=0)
#     389 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 391 async for chunk in chunks:
#     392     # Track first byte time when we get first content
#     393     if first_byte_time is None and ("contentBlockDelta" in chunk or "contentBlockStart" in chunk):
#     394         first_byte_time = time.time()
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\models\bedrock.py:647, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, system_prompt_content, **kwargs)
#     643         break
#     645     yield event
# --> 647 await task
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\strands\models\bedrock.py:686, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     684 # Track tool use events to fix stopReason for streaming responses
#     685 has_tool_use = False
# --> 686 for chunk in response["stream"]:
#     687     if (
#     688         "metadata" in chunk
#     689         and "trace" in chunk["metadata"]
#     690         and "guardrail" in chunk["metadata"]["trace"]
#     691     ):
#     692         guardrail_data = chunk["metadata"]["trace"]["guardrail"]
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\botocore\eventstream.py:591, in EventStream.__iter__(self)
#     590 def __iter__(self):
# --> 591     for event in self._event_generator:
#     592         parsed_event = self._parse_event(event)
#     593         if parsed_event:
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\botocore\eventstream.py:598, in EventStream._create_raw_event_generator(self)
#     596 def _create_raw_event_generator(self):
#     597     event_stream_buffer = EventStreamBuffer()
# --> 598     for chunk in self._raw_stream.stream():
#     599         event_stream_buffer.add_data(chunk)
#     600         yield from event_stream_buffer
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\urllib3\response.py:1088, in HTTPResponse.stream(self, amt, decode_content)
#    1072 """
#    1073 A generator wrapper for the read() method. A call will block until
#    1074 ``amt`` bytes have been read from the connection or until the
#    (...)   1085     'content-encoding' header.
#    1086 """
#    1087 if self.chunked and self.supports_chunked_reads():
# -> 1088     yield from self.read_chunked(amt, decode_content=decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\urllib3\response.py:1248, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1245     amt = None
#    1247 while True:
# -> 1248     self._update_chunk_length()
#    1249     if self.chunk_left == 0:
#    1250         break
#
# File c:\Users\r.laface\Desktop\Codice\aws-agentcore\.venv\Lib\site-packages\urllib3\response.py:1178, in HTTPResponse._update_chunk_length(self)
#    1175     raise InvalidChunkLength(self, line) from None
#    1176 else:
#    1177     # Truncated at start of next chunk
# -> 1178     raise ProtocolError("Response ended prematurely") from None
#
# ProtocolError: Response ended prematurely

# %%
import requests
import json

CLIENT_ID = client_id
CLIENT_SECRET = client_secret
TOKEN_URL = "https://agentcore-85bb2461.auth.us-east-1.amazoncognito.com/oauth2/token"

def fetch_access_token(client_id, client_secret, token_url):
  response = requests.post(
    token_url,
    data="grant_type=client_credentials&client_id={client_id}&client_secret={client_secret}".format(client_id=client_id, client_secret=client_secret),
    headers={'Content-Type': 'application/x-www-form-urlencoded'}
  )

  return response.json()['access_token']

def list_tools(gateway_url, access_token):
  headers = {
      "Content-Type": "application/json",
      "Authorization": f"Bearer {access_token}"
  }

  payload = {
      "jsonrpc": "2.0",
      "id": "list-tools-request",
      "method": "tools/list"
  }

  response = requests.post(gateway_url, headers=headers, json=payload)
  return response.json()

# Example usage
gateway_url = "https://taskapigateway-vveeifneus.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp"
access_token = fetch_access_token(CLIENT_ID, CLIENT_SECRET, TOKEN_URL)
tools = list_tools(gateway_url, access_token)
print(json.dumps(tools, indent=2))
# Out:
# {
#   "jsonrpc": "2.0",
#   "id": "list-tools-request",
#   "result": {
#     "tools": [
#       {
#         "inputSchema": {
#           "type": "object",
#           "properties": {
#             "query": {
#               "type": "string"
#             }
#           },
#           "required": [
#             "query"
#           ]
#         },
#         "name": "x_amz_bedrock_agentcore_search",
#         "description": "A special tool that returns a trimmed down list of tools given a context. Use this tool only when there are many tools available and you want to get a subset that matches the provided context."
#       },
#       {
#         "inputSchema": {
#           "type": "object",
#           "properties": {
#             "due_date": {
#               "type": "string"
#             },
#             "status": {
#               "type": "string"
#             }
#           }
#         },
#         "name": "get-tasks___get-tasks",
#         "description": "Retrieve tasks from database"
#       },
#       {
#         "inputSchema": {
#           "type": "object",
#           "properties": {
#             "dueDate": {
#               "description": "Data di scadenza del task in formato ISO 8601 (YYYY-MM-DD)",
#               "type": "string"
#             },
#             "description": {
#               "description": "Descrizione dettagliata del task",
#               "type": "string"
#             },
#             "priority": {
#               "description": "Priorit\u00e0 del task. Valori ammessi: low, medium, high",
#               "type": "string"
#             },
#             "title": {
#               "description": "Titolo del task (obbligatorio)",
#               "type": "string"
#             },
#             "taskId": {
#               "description": "ID del task esistente da aggiornare. Se omesso, viene creato un nuovo task.",
#               "type": "string"
#             },
#             "status": {
#               "description": "Stato del task. Valori ammessi: pending, in_progress, completed",
#               "type": "string"
#             }
#           },
#           "required": [
#             "title"
#           ]
#         },
#         "name": "save-task___save-task",
#         "description": "Crea o aggiorna un task nel sistema di gestione task. Utilizza taskId per aggiornare un task esistente, altrimenti crea un nuovo task."
#       }
#     ]
#   }
# }

# %% [markdown]
# **Issue: if you get below error while executing below cell, it indicates incompatibily between pydantic and pydantic-core versions.**
#
# ```
# TypeError: model_schema() got an unexpected keyword argument 'generic_origin'
# ```
# **How to resolve?**
#
# You will need to make sure you have pydantic==2.7.2 and pydantic-core 2.27.2 that are both compatible. Restart the kernel once done.

# %% [markdown]
# # Clean up
#
# Additional resources are also created like IAM role, IAM Policies, Credentials provider, AWS Lambda functions, Cognito user pools, s3 buckets that you might need to manually delete as part of the clean up. This depends on the example you run.

# %% [markdown]
# ## Delete the gateway (Optional)

# %%
# import utils
# utils.delete_gateway(gateway_client,gatewayID)
